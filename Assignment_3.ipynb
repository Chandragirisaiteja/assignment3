# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA



plt.axis('on')
plt.grid(True)

#centre and radius of circles
O=np.array([0,0])
r=3.05
#Plotting the circle of radius 3.05
c= 3.05
plt.plot(x,y,label='$circle with (r=3.05)$')
